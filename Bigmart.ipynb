# %% [markdown]
# <a href="https://colab.research.google.com/github/sathya0525/sathya5/blob/main/Bigmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATASET DESCRIPTION

# %% [markdown]
# 1) The project dataset have been divided into two the TRAIN and TEST datasets where the former have 8523 rows and 12 columns and the later have 5681 rows and 11 columns.

# %% [markdown]
# 2) We could find that the target column in the train set is **item_outlet_sales where it is the sales of the items in the particula output**.

# %% [markdown]
# 3) **item_identifier**--These are set of unique values to access the item.

# %% [markdown]
# 4)**item_Weight**--Weights of the individual items.

# %% [markdown]
# 5)**item_Fat_Content**--Tells about the fat content present in each items.

# %% [markdown]
# 6)**item_Visibility**--The percentage of display area of the time.

# %% [markdown]
# 7)**item_Type**--it is the products that are kept for sale.

# %% [markdown]
# 8)**item_MRP**--The Maximum retail price for every item in a store.

# %% [markdown]
# 9)**Outlet_identifier**--these are unique number to identify the outlets.

# %% [markdown]
# 10)**Outlet_Establishment_Year**--The year in which the outlet was established.

# %% [markdown]
# 11)**Outlet_Size**--the area or the size of the outlet.

# %% [markdown]
# 12)**Outlet_Location_Type**--The location type of a outlet.

# %% [markdown]
# 13)**Outlet_Type**--Tells about the type whether its a super market or a grocery store.

# %% [markdown]
# **Bigmart sales analysis**

# %% [markdown]
# # 2) HYPOTHESIS GENERATION:

# %% [markdown]
# **Sales of a particular product are influenced by its price**

# %% [markdown]
# **EXPLANATION:The price of a product may influence customer purchasing decisions,with higher prices leading to lower sales,and lower price leading to higher sales.**

# %% [markdown]
# # 3) IMPORTING THE LIBRARIES:

# %%
import numpy as np
import pandas as pd

# impoting the required libraries for the analysis of the project.

# %% [markdown]
# **Here we are importing the libraries like Numpy,pandas,matplotlib,seaborn which are used in the data loading,data cleaning and data preprocessing process**

# %% [markdown]
# ## loading the data

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Train.csv')

#importing the required libraries and load dataset

# %%
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Test.csv')

#importing necessary libraries and load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Big_Mart Dataset/Train.csv')

# %%
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Big_Mart Dataset/Test.csv')

# %% [markdown]
# **Data Structure and Content**

# %%
train.shape
# shape functions us Identify how many rows and columns we have according to our data set.
# Out:
# (8523, 12)

# %%
train.columns
#display columns names
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train.isnull().sum()
#display number of missing values of each column
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train.dtypes
#display the data type of each column
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
train.duplicated()
#chech the duplicated rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
train.info()
#display information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train.describe()
#display descriptive statistics
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.head()
#display first few rows of datasets
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
train.tail()
#display last few rows of datasets
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
train['Item_Type'].value_counts()
#display the value counts for 'Item_Types'
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].value_counts()
#display value count for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %% [markdown]
# # DATA STRUCURE AND FUNCTION

# %%
test.shape
#shape function helps us identify how many rows and columns we have according to our datasets
# Out:
# (5681, 11)

# %%
test.columns
#display column names
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
test.isnull().sum()
#display number of missing values in each columns
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
test.dtypes
#display the data type of each column
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
test.duplicated()
#check for duplicate rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
test.info()
#display information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test.describe()
#display descriptive statistics
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
test.head()
#dispaly the first few rows of the datasets
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
test.tail()
#display last few rows of the datasets
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1

# %%
test['Item_Type'].value_counts()
#display value count for 'Item_Type'
# Out:
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
#display value count for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %%
train['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)
#replace inconsistent values in 'Item_Fat_Content'

# %%
train['Item_Fat_Content'].value_counts()
#display updated value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# # Explaratory data analysis

# %% [markdown]
# uni variable analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors
# import Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content' , data=train)
plt.xlabel('Item_Fat_Content')
plt.show()
# A countplot is a type of data visualization used in python.
# It is particularly useful for visualising the count occurences of each unique value.
# The sns.countplot function is used to create the count plot.
# The items have more low fat content and moderate regular fat content.

# %% [markdown]
# n this we have plotted the graph using train datas. so here the low fat content quantity is higher compared to regular

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Item_Type',data=train)
plt.ylabel('Item_Type')
plt.show()

# %% [markdown]
# In this we have plotted the graph using train datas.here the snacksfoods,fruits and vegtable count is higher and sea food count is lower

# %%
outletsize=train['Outlet_Size'].value_counts(normalize=True)*100
explode=(0.05,0.06,0.07)
colors=('green','purple','pink')
plt.pie(outletsize,labels=outletsize.index,autopct='%1.1f%%',explode=explode,colors=colors)
plt.title('%outletsize')
plt.axis('equal')
plt.show()

# %% [markdown]
# In this pichart medium size outlet is higher and high size outlet is lower

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Size' , data=train)
plt.xlabel('Outlet_Size')
plt.show()

# %% [markdown]
# In this we have plotted the graph using train datas.medium size outlet is higher and small high outlet is lower

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Location_Type' , data=train)
plt.xlabel('Outlet_Location_Type')
plt.show()

# %% [markdown]
# In this graph the outlet location type of tier 3 has higher count and tier 2 has the lowest count when compared to others

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Establishment_Year',data=train)
plt.ylabel('Outlet_Establishment_Year')
plt.show()

# %% [markdown]
# In this graph establishment year and their count is plotted.And the year 1985 has the highest count whereas 1998 is the lowest

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Identifier',data=train)
plt.ylabel('Outlet_Identifier')
plt.show()

# %% [markdown]
# Here the outlet identifier and their count is plotted and OUT049 And OUT018 are the ones with highest count and OUT010 Is the one with lowest count

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Location_Type',data=train)
plt.ylabel('Outlet_Location_Type')
plt.show()

# %% [markdown]
# In this graph the outlet location type of tier 3 has higher count and tier 2 has the lowest count when compared to others

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Type',data=train)
plt.ylabel('Outlet_Type')
plt.show()

# %% [markdown]
# in this graph the outlet type is plotted and supermarket Type 1 is one with highest value and spermarket Type 2 is the one with the lowest value

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Item_Fat_Content',data=train)
plt.ylabel('Item_Fat_Content')
plt.show()

# %% [markdown]
# In this graph the item fat count is plotted, and the low fat has the highest count and the vise versa with regular

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Location_Type' , data=test)
plt.ylabel('Outlet_Location_Type')
plt.show()

# %% [markdown]
# here the test dataframe is used. outlet location type is plotted, and the tier 3 has the greatest count and tier 1 has the lowest count

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content' , data=test)
plt.xlabel('Item_Fat_Content')
plt.show()

# %% [markdown]
# In this we have plotted the graph using test datas. so here the low fat content is named as 0 and it is higher in quantity compared to regular which is named as 1

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Item_Type',data=test)
plt.ylabel('Item_Type')
plt.show()

# %% [markdown]
# In this we have plotted the graph using train datas.here the snacksfoods,fruits and vegtable count is higher and sea food count is lower

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Type',data=test)
plt.ylabel('Outlet_Type')
plt.show()

# %% [markdown]
# supermarket type 1 is high where as supermarket type 2 is low in count when compared to others

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Establishment_Year',data=test)
plt.ylabel('Outlet_Establishment_Year')
plt.show()

# %% [markdown]
# The establishment year from(1985-2009) is given in this graph.so the count is higher in the year 1985 whereas lower in the year 1998 and the year 1987,1997 and(1992-2009) are equivalent

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Identifier',data=test)
plt.ylabel('Outlet_Identifier')
plt.show()

# %% [markdown]
# The image shows a horizontal bar chart depicting the count of outlet_identifier OUTO49,OUTO17,OUTO27,OUTO46,OUTO18,OUTO45,OUTO13,OUTO35 has the maximum count

# %% [markdown]
# # To handle the Missing and catagorical values

# %%
# To handle the Missing and null values
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
# Coverting the labels into a numeric form using Label Encoder for the TRAIN SET.
le=LabelEncoder()
for col in train.columns:
    if train[col].dtype=='object':
        train[col]=le.fit_transform(train[col])

# %%
train['Outlet_Size'].dtypes
#display the data type of 'Outlet_Size' column
# Out:
# dtype('int64')

# %%
train.head()
#display first few rows of the datasets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            3
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %%
imputer=SimpleImputer(strategy='mean')
missing_coloums=['Item_Weight','Outlet_Size']
train[missing_coloums]=imputer.fit_transform(train[missing_coloums])
# Fill missing values in 'Item_Weight'and 'Outlet_Size' columns with their respective column means.

# %%
train.isnull().sum()
#display the number of missing values
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
# Coverting the labels into a numeric form using Label Encoder for the TEST SET.
le=LabelEncoder()
for col in test.columns:
    if test[col].dtype=='object':
        test[col]=le.fit_transform(test[col])

# %%
test['Outlet_Size'].dtypes
#display the data type of 'Outlet_Size' column
# Out:
# dtype('int64')

# %%
test.head()
#display first few rows of the datasets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103       20.750                 1         0.007565         13
# 1             1067        8.300                 4         0.038428          4
# 2             1406       14.600                 1         0.099575         11
# 3              809        7.315                 1         0.015388         13
# 4             1184          NaN                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999            1
# 1   87.3198                  2                       2007            3
# 2  241.7538                  0                       1998            3
# 3  155.0340                  2                       2007            3
# 4  234.2300                  5                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3

# %%
imputer=SimpleImputer(strategy='mean')
missing_coloums=['Item_Weight','Outlet_Size']
test[missing_coloums]=imputer.fit_transform(test[missing_coloums])
# Fill missing values in 'Item_Weight'and 'Outlet_Size' columns with their respective column means.

# %%
test.isnull().sum()
#display the number osf missing values
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# # handling the outliers

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5,))
number_columns.boxplot(ax=ax,vert=False,color='green')
plt.title('identifying outliers')
plt.show()
#When exploring data, the outliers are the extreme values within the dataset. That means the outlier data points vary greatly from the expected values—either being much larger or significantly smaller.here we use train dataset here.

# %% [markdown]
# Box plots are useful because they show minimum and maximum values, the median, and the interquartile range of the data. In the chart, the outliers are shown as points which makes them easy to see.

# %%
number_columns=test.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5,))
number_columns.boxplot(ax=ax,vert=False,color='purple')
plt.title('identifying outliers')
plt.show()

# %% [markdown]
# Box plots are useful because they show minimum and maximum values, the median, and the interquartile range of the data. In the chart, the outliers are shown as points which makes them easy to see.

# %%
## Assuming 'train' is a DataFrame and 'Item_Outlet_Sales' is a column in it
q1=np.percentile(train['Item_Outlet_Sales'],25)
q3=np.percentile(train['Item_Outlet_Sales'],75)
iqr=q3-q1
print('q1',q1)
print('q3',q3)
print('IQR',iqr)
# Out:
# q1 834.2474
# q3 3101.2964
# IQR 2267.049

# %%
upperlimit=q3+1.5*iqr
lowerlimit=q1-1.5*iqr
print('upperlimit',upperlimit)
print('lowerlimit',lowerlimit)
# Calculate the upper and lower bounds for outlier detection
# Out:
# upperlimit 6501.8699
# lowerlimit -2566.3261

# %% [markdown]
# # cube transformation

# %%
print(train.columns)
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train['Outlet_sales_cube']=np.cbrt(train['Item_Outlet_Sales'])
# Computes the cube root of the sales data.

# %%
## Apply cube root transformation
train['Outlet_Sales_Square']=np.cbrt(train['Item_Outlet_Sales'])
train['Outlet_Sales_Cube']=np.cbrt(train['Item_Outlet_Sales'])
# Select numeric columns
number_columns=train.select_dtypes(include=['int64','float64'])
# Create boxplot
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()

# %% [markdown]
# The above graph consists of outliers in the columns of Outlet_Sales_Cube,Outlet_type,Item_Visibility,Item_outlet_size and Item_fat_content
#
# in the columns of 1,13,11 and 12 consists of outliers within the range whereas column 2 consists of outliers out of range

# %% [markdown]
# Bi variant analysis

# %%
sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# Plot distribution with KDE and rug plot
# Out:
# <ipython-input-345-605f403d5255>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# The outliers ranging from (0-7k)
# whereas outliers is also present in the range from 8k to 13k but with plentier amount

# %%
print(train.columns)
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Item_MRP', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Outlet_sales_cube',
#        'Outlet_Sales_Cube', 'Outlet_Age'],
#       dtype='object')

# %%
train['Outlet_Sales_Square']=np.sqrt(train['Item_Outlet_Sales'])

# %%
## Apply cube root transformation
train['Outlet_Sales_Square']=np.sqrt(train['Item_Outlet_Sales'])
train['Outlet_Sales_Cube']=np.cbrt(train['Item_Outlet_Sales'])
# Select numeric columns
number_columns=train.select_dtypes(include=['int64','float64'])
# Create boxplot
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()

# %%
sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# Plot distribution with KDE and rug plot
# Out:
# <ipython-input-393-605f403d5255>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
# Plot distribution with KDE and rug plot for Outlet_Sales_Square
sns.distplot(a=train['Outlet_Sales_Square'],kde=True,rug=True)
# Out:
# <ipython-input-395-f7ae5288721f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Square'],kde=True,rug=True)
# <Axes: xlabel='Outlet_Sales_Square', ylabel='Density'>

# %%
# Set the size of the figure
plt.figure(figsize=(8,8))

# Create a bar plot with 'Item_Outlet_Sales' on the x-axis and 'Item_Type' on the y-axis
sns.barplot(x='Item_Outlet_Sales', y='Item_Type', data=train).set(title='Item Type vs Outlet Sales')

# Set the labels for the x and y axes
plt.xlabel('Item Outlet Sales')
plt.ylabel('Item Type')

# Display the plot
plt.show()

# %% [markdown]
# In the above graph seafood consists of more outliers when compared to others

# %% [markdown]
# multivariate analysis

# %%
# Subset the dataset to include only the relevant columns
subset = train[['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
             'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
             'Item_Outlet_Sales','Outlet_sales_cube']]

# Calculate the correlation matrix
corr = subset.corr()

# Create a mask for the upper triangle of the heatmap
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 8))

# Generate the heatmap with green and white colors
sns.heatmap(corr, mask=mask, annot=True, cmap=sns.diverging_palette(20, 220, n=200),
            center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Set the title and labels for the plot
ax.set_title("Correlation Heatmap", fontsize=18)
ax.set_xlabel("Features", fontsize=14)
ax.set_ylabel("Features", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
train.head()
#display first few rows of datasets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  Outlet_sales_cube  \
# 0                     0            1          3735.1380          15.515611
# 1                     2            2           443.4228           7.625576
# 2                     0            1          2097.2700          12.800240
# 3                     2            0           732.3800           9.013888
# 4                     2            1           994.7052           9.982319
#
#    Outlet_Sales_Square  Outlet_Sales_Cube
# 0            15.515611          15.515611
# 1             7.625576           7.625576
# 2            12.800240          12.800240
# 3             9.013888           9.013888
# 4             9.982319           9.982319

# %%
train['Outlet_Age']=train['Outlet_Establishment_Year'].apply(lambda year: 2024-year)
#adding a new column to train data called Outlet_Age, which calculates the age of each outlet based on the establishment year.

# %%
train.head()
#display first few rows of datasets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  Outlet_sales_cube  \
# 0                     0            1          3735.1380          15.515611
# 1                     2            2           443.4228           7.625576
# 2                     0            1          2097.2700          12.800240
# 3                     2            0           732.3800           9.013888
# 4                     2            1           994.7052           9.982319
#
#    Outlet_Sales_Square  Outlet_Sales_Cube  Outlet_Age
# 0            15.515611          15.515611          25
# 1             7.625576           7.625576          15
# 2            12.800240          12.800240          25
# 3             9.013888           9.013888          26
# 4             9.982319           9.982319          37

# %%
train=train.drop(['Item_Identifier','Item_Weight','Item_Visibility','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size'],axis=1)
#Removing unnecessary columns from train that are not needed for your analysis or modeling.

# %%
train=train.drop(['Outlet_Sales_Square'],axis=1)
#adding a new column to test data called Outlet_Age, which calculates the age of each outlet based on the establishment year.

# %%
train.head()
#display first few rows of datasets
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 0          4  249.8092                     0            1
# 1                 1         14   48.2692                     2            2
# 2                 0         10  141.6180                     0            1
# 3                 1          6  182.0950                     2            0
# 4                 0          9   53.8614                     2            1
#
#    Item_Outlet_Sales  Outlet_sales_cube  Outlet_Sales_Cube  Outlet_Age
# 0          3735.1380          15.515611          15.515611          25
# 1           443.4228           7.625576           7.625576          15
# 2          2097.2700          12.800240          12.800240          25
# 3           732.3800           9.013888           9.013888          26
# 4           994.7052           9.982319           9.982319          37

# %%
from sklearn.preprocessing import StandardScaler
#Initialize the scaler

# %%
x=train[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
y=train['Outlet_sales_cube']
# set feature matrix X and target vector y for a machine learning model.

# %%
x.shape
# Out:
# (8523, 6)

# %%
scaler=StandardScaler()
#Initialize the scaler

# %%
x=scaler.fit_transform(x)
# Fit and transform the training data

# %%
x=pd.DataFrame(x)
# Convert x to DataFrame if it is not already one

# %%
print(x)
# Check the Datasets
# Out:
#              0         1         2         3         4         5
# 0    -0.738147 -0.766479  1.747454 -1.369334 -0.252658 -0.139541
# 1     1.354743  1.608963 -1.489023  1.091569  1.002972 -1.334103
# 2    -0.738147  0.658786  0.010040 -1.369334 -0.252658 -0.139541
# 3     1.354743 -0.291391  0.660050  1.091569 -1.508289 -0.020085
# 4    -0.738147  0.421242 -1.399220  1.091569 -0.252658  1.293934
# ...        ...       ...       ...       ...       ...       ...
# 8518 -0.738147  1.371418  1.180783  1.091569 -0.252658  1.293934
# 8519  1.354743 -1.716656 -0.527301 -0.138882 -0.252658 -0.497909
# 8520 -0.738147  0.183698 -0.897208 -0.138882 -0.252658 -0.736822
# 8521  1.354743  1.371418 -0.607977  1.091569  1.002972 -1.334103
# 8522 -0.738147  1.608963 -1.052261 -1.369334 -0.252658  0.099372
#
# [8523 rows x 6 columns]

# %%
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
test.head()
#display first few rows of datasets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 1         0.007565         13
# 1             1067     8.300000                 4         0.038428          4
# 2             1406    14.600000                 1         0.099575         11
# 3              809     7.315000                 1         0.015388         13
# 4             1184    12.695633                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3

# %%
test['Outlet_Age']=test['Outlet_Establishment_Year'].apply(lambda year: 2024-year)
#adding a new column to train data called Outlet_Age, which calculates the age of each outlet based on the establishment year.

# %%
test.head()
#display first few rows of datasets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 1         0.007565         13
# 1             1067     8.300000                 4         0.038428          4
# 2             1406    14.600000                 1         0.099575         11
# 3              809     7.315000                 1         0.015388         13
# 4             1184    12.695633                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type  Outlet_Age
# 0                     0            1          25
# 1                     1            1          17
# 2                     2            0          26
# 3                     1            1          17
# 4                     2            3          39

# %%
test=test.drop(['Item_Identifier','Item_Weight','Item_Visibility','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size',],axis=1)
#Removing unnecessary columns from train that are not needed for your analysis or modeling.

# %%
test.head()
#display first few row of datasets
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 1         13  107.8622                     0            1
# 1                 4          4   87.3198                     1            1
# 2                 1         11  241.7538                     2            0
# 3                 1         13  155.0340                     1            1
# 4                 2          4  234.2300                     2            3
#
#    Outlet_Age
# 0          25
# 1          17
# 2          26
# 3          17
# 4          39

# %%
from sklearn.preprocessing import StandardScaler
#Initialize the scaler

# %%
x=test[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
# set feature matrix X and target vector y for a machine learning model.

# %%
test.shape
# Out:
# (5681, 6)

# %%
scaler=StandardScaler()
#Initialize the scaler

# %%
test=scaler.fit_transform(test)
# Fit and transform the training data

# %%
test=pd.DataFrame(test)
# Convert x to DataFrame if it is not already one

# %%
test.head()
#display first few rows of datasets
# Out:
#           0         1         2         3         4         5
# 0 -0.575284  1.366916 -0.536555 -1.369215 -0.252769 -0.139891
# 1  4.104698 -0.766450 -0.868937 -0.138827 -0.252769 -1.095512
# 2 -0.575284  0.892835  1.629848  1.091560 -1.507994 -0.020438
# 3 -0.575284  1.366916  0.226697 -0.138827 -0.252769 -1.095512
# 4  0.984710 -0.766450  1.508110  1.091560  2.257683  1.532446

# %%
print(test)
# Check the Datasets
# Out:
#              0         1         2         3         4         5
# 0    -0.575284  1.366916 -0.536555 -1.369215 -0.252769 -0.139891
# 1     4.104698 -0.766450 -0.868937 -0.138827 -0.252769 -1.095512
# 2    -0.575284  0.892835  1.629848  1.091560 -1.507994 -0.020438
# 3    -0.575284  1.366916  0.226697 -0.138827 -0.252769 -1.095512
# 4     0.984710 -0.766450  1.508110  1.091560  2.257683  1.532446
# ...        ...       ...       ...       ...       ...       ...
# 5676  0.984710  1.366916  0.004727 -1.369215 -0.252769  0.099015
# 5677  0.984710  1.840998  0.455014  1.091560  1.002457 -1.334417
# 5678 -0.575284  0.181713 -0.360485 -0.138827 -0.252769 -0.498248
# 5679  0.984710 -1.003490  1.190844 -0.138827 -0.252769 -1.095512
# 5680  0.984710 -1.003490 -0.990674 -0.138827 -0.252769 -0.498248
#
# [5681 rows x 6 columns]

# %% [markdown]
# # BUILDING THE MODEL

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression
# For evaluating the models using the metrics
from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.model_selection  import cross_val_score as CVS

# %% [markdown]
# Using Simple Linear Regression Algorithm:

# %%
# Define the linear regression model
lr = LinearRegression()

# Train the model on the training data
lr.fit(X, y)

# Precting the model using the test set
y_predict = lr.predict(X)

# Evaluating the training set with the metric values

print("R-Square value on the training set: = ", lr.score(x,y))
print("----------------------------------------------------------------------------------------------")

# Use cross-validation to get the R-squared score
scores = CVS(lr, X, y, cv=5)
print('CV R-squared scores:', scores,"\n")
print('Average CV R-squared score:', np.mean(scores),"\n")

# %% [markdown]
# # Saving the model:

# %%
import pickle
#serialize and deserialize data types

# %%
Bigmart= "BigMart_Analysis.sav"
pickle.dump(lr,open(Bigmart,'wb'))
# Save the model

# %% [markdown]
# # SUMMARY:

# %% [markdown]
#  1.In this bigmart sales analysis project we started by exploring and cleaning the dataset. we checked for missing values,duplicates,and outliers in the data and handled them accordingly.
#
#  2.We also did some feature engineering to extract useful information from the given features.
#
#  3.Afterpreprocessing the data,the training and testing sets were applied to the linear regression,random forest,lasso regression algorithms to build our regression model.
#
#  4.We evaluated our models performance using various metrics such as R-squared and cross validation scores.we also visualized the feature importance using a heat map.
#
#  5.We also made some important observation from the feature importance plot Item_MRP,Outlet_Type,and Item_Outlet_Sales were the most important features for predicting the sales.
